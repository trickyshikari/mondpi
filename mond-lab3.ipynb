# %% [markdown]
# Using scipy’s quad function, write a program that solves the following integral numerically

# %%
from math import  pi
from scipy.integrate import quad
import matplotlib.pyplot as plt
import numpy as np

# function we want to integrate
def f(x):
    return np.cos(2 * pi * x)

# call quad to integrate f from -2 to 2
res, err = quad(f, 0, 1)

print("The numerical result is {:f} (+-{:g})"
    .format(res, err))
# Out:
# The numerical result is 0.000000 (+-7.11699e-15)

# %% [markdown]
# f(x) = cos(2*pi*X);
# F(x) = sin(2*pi*X)/2pi;
# F(1) - F(0) = 0;

# %%
def plotquad(f,a,b):
    x = np.linspace(a,b,500)
    
    f_values = f(x)
    
    plt.plot(x,f_values)
    plt.title('f(x)=cos(2piX)')
    plt.show()
    
    num_integral, err = quad(f,a,b)
    return num_integral, err
    
res, err = plotquad(f,0,1)

print("The numerical result is {:f} (+-{:g})"
    .format(res, err))
# Out:
# The numerical result is 0.000000 (+-7.11699e-15)
